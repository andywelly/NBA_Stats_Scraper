# %%
from bs4 import BeautifulSoup
import requests as rq

# %%
with open('home.html', 'r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content, 'lxml')
    table = soup.find('tbody', class_="Crom_body__UYOcU")
    rows = table.find_all('tr')
    
    for row in rows:
        col = row.find_all('td')
        rank = col[0].text
        name = col[1].text
        points = col[8].text
        print(rank + ": " + name + "ppg: " + points + "\n")
        print("\n")
# Out:
# 1: Luka Doncicppg: 34.8
#
#
#
# 2: Shai Gilgeous-Alexanderppg: 30.9
#
#
#
# 3: Giannis Antetokounmpoppg: 29.6
#
#
#
# 4: Jayson Tatumppg: 28.0
#
#
#
# 4: Tyrese Maxeyppg: 28.0
#
#
#
# 6: Anthony Edwardsppg: 27.4
#
#
#
# 7: Jalen Brunsonppg: 27.0
#
#
#
# 8: LeBron Jamesppg: 26.8
#
#
#
# 9: Kyrie Irvingppg: 26.5
#
#
#
# 10: Donovan Mitchellppg: 26.4
#
#
#
# 11: De'Aaron Foxppg: 26.0
#
#
#
# 12: DeMar DeRozanppg: 25.9
#
#
#
# 13: Anthony Davisppg: 25.5
#
#
#
# 13: Devin Bookerppg: 25.5
#
#
#
# 13: Kevin Durantppg: 25.5
#
#
#
# 16: Jaren Jackson Jr.ppg: 24.3
#
#
#
# 16: Jimmy Butlerppg: 24.3
#
#
#
# 18: Kyle Kuzmappg: 24.2
#
#
#
# 19: Nikola Jokicppg: 24.0
#
#
#
# 20: Jaylen Brownppg: 23.8
#
#
#
# 21: Paolo Bancheroppg: 23.1
#
#
#
# 22: Kawhi Leonardppg: 23.0
#
#
#
# 23: Victor Wembanyamappg: 22.8
#
#
#
# 24: Stephen Curryppg: 22.7
#
#
#
# 25: Kristaps Porzingisppg: 22.6
#
#
#
# 26: Damian Lillardppg: 22.6
#
#
#
# 27: Dejounte Murrayppg: 22.1
#
#
#
# 28: Brandon Ingramppg: 21.6
#
#
#
# 29: Collin Sextonppg: 21.5
#
#
#
# 30: Cade Cunninghamppg: 21.4
#
#
#
# 31: Michael Porter Jr.ppg: 21.2
#
#
#
# 32: Paul Georgeppg: 21.1
#
#
#
# 33: Alperen Sengunppg: 21.1
#
#
#
# 34: Anfernee Simonsppg: 21.0
#
#
#
# 34: Devin Vassellppg: 21.0
#
#
#
# 34: Tyler Herroppg: 21.0
#
#
#
# 37: Bam Adebayoppg: 20.9
#
#
#
# 38: Zion Williamsonppg: 20.8
#
#
#
# 39: Coby Whiteppg: 20.5
#
#
#
# 39: D'Angelo Russellppg: 20.5
#
#
#
# 41: Jerami Grantppg: 20.4
#
#
#
# 42: Jalen Williamsppg: 20.4
#
#
#
# 43: Nikola Vucevicppg: 19.9
#
#
#
# 44: Deni Avdijappg: 19.9
#
#
#
# 45: Domantas Sabonisppg: 19.8
#
#
#
# 46: Lauri Markkanenppg: 19.8
#
#
#
# 47: Jordan Pooleppg: 19.7
#
#
#
# 48: Trae Youngppg: 19.4
#
#
#
# 49: Donte DiVincenzoppg: 19.3
#
#
#
# 49: Karl-Anthony Townsppg: 19.3
