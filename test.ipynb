# %%
import requests
from bs4 import BeautifulSoup

page = requests.get("https://www.statmuse.com/nba/scores?date=2025-03-09")
soup = BeautifulSoup(page.text, "html.parser")

# Find all game links
games = soup.find_all("div")

print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"> <head><meta content="dark light" name="color-scheme"/><script>
#       function setTheme(document) {
#         const metaColorScheme = document.querySelector(
#           'meta[name="color-scheme"]',
#         )
#
#         if (window.colorScheme) {
#           if (window.colorScheme === 'dark') {
#             document.documentElement.classList.add('dark')
#             metaColorScheme.setAttribute('content', 'dark')
#           } else {
#             document.documentElement.classList.remove('dark')
#             metaColorScheme.setAttribute('content', 'light')
#           }
#         } else {
#           if (
#             localStorage.theme === 'dark' ||
#             (!('theme' in localStorage) &&
#               window.matchMedia('(prefers-color-scheme: dark)').matches)
#           ) {
#             document.documentElement.classList.add('dark')
#             metaColorScheme.setAttribute('content', 'dark')
#           } else {
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time

# Set up Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode

# Set up the WebDriver
service = Service("/usr/local/bin/chromedriver")  # Replace with your chromedriver path
driver = webdriver.Chrome(service=service, options=chrome_options)

# Load the page
driver.get("https://sports.yahoo.com/nba/brooklyn-nets-charlotte-hornets-2025030830/")

# Wait for the content to load
time.sleep(5)  # Adjust the sleep time as needed

# Get the page source
page_source = driver.page_source

# Close the browser
driver.quit()

# Parse the page source with BeautifulSoup
soup = BeautifulSoup(page_source, "html.parser")

print(soup)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[19], line 13
#      11 # Set up the WebDriver
#      12 service = Service("/usr/local/bin/chromedriver")  # Replace with your chromedriver path
# ---> 13 driver = webdriver.Chrome(service=service, options=chrome_options)
#      15 # Load the page
#      16 driver.get("https://sports.yahoo.com/nba/brooklyn-nets-charlotte-hornets-2025030830/")
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/chrome/webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
# ...

# %%
robots = requests.get("https://www.actionnetwork.com/robots.txt")
print(robots.text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <HTML><HEAD><META HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=iso-8859-1">
# <TITLE>ERROR: The request could not be satisfied</TITLE>
# </HEAD><BODY>
# <H1>403 ERROR</H1>
# <H2>The request could not be satisfied.</H2>
# <HR noshade size="1px">
# Request blocked.
# We can't connect to the server for this app or website at this time. There might be too much traffic or a configuration error. Try again later, or contact the app or website owner.
# <BR clear="all">
# If you provide content to customers through CloudFront, you can find steps to troubleshoot and help prevent this error by reviewing the CloudFront documentation.
# <BR clear="all">
# <HR noshade size="1px">
# <PRE>
# Generated by cloudfront (CloudFront)
# Request ID: 7gaw9PW-Mo6QskyllXmIPLKYUNpfFb43F5XbziemkkQGg8IqH4q21A==
# </PRE>
# <ADDRESS>
# </ADDRESS>
# </BODY></HTML>
