# %%
import pandas as pd
import requests
pd.set_option('display.max_columns', None)
import time
import numpy as np

# %%
test_url = 'https://stats.nba.com/stats/leagueLeaders?LeagueID=00&PerMode=PerGame&Scope=S&Season=2023-24&SeasonType=Regular%20Season&StatCategory=PTS'

# %%
r = requests.get(url=test_url).json()

# %%
table_headers = r['resultSet']['headers']

# %%
pd.DataFrame(r['resultSet']['rowSet'], columns=table_headers)
# Out:
#      PLAYER_ID  RANK                   PLAYER     TEAM_ID TEAM  GP   MIN  \
# 0      1629029     1              Luka Doncic  1610612742  DAL  53  37.5
# 1      1628983     2  Shai Gilgeous-Alexander  1610612760  OKC  59  34.5
# 2       203507     3    Giannis Antetokounmpo  1610612749  MIL  59  34.9
# 3      1628378     4         Donovan Mitchell  1610612739  CLE  47  35.7
# 4       201142     5             Kevin Durant  1610612756  PHX  54  37.2
# ..         ...   ...                      ...         ...  ...  ..   ...
# 254    1629726   255         Garrison Mathews  1610612737  ATL  44  12.8
# 255    1630192   256               Zeke Nnaji  1610612743  DEN  46   9.8
# 256     202397   257                Ish Smith  1610612766  CHA  43  17.2
# 257    1630550   258                  JT Thor  1610612766  CHA  47  12.7
# 258    1641748   259        Andre Jackson Jr.  1610612749  MIL  47  10.6
#
#       FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM   FTA  FT_PCT  OREB  DREB  \
# 0    11.7  23.7   0.496   3.9  10.2    0.380  7.2   9.2   0.784   0.8   8.1
# 1    11.1  20.2   0.548   1.3   3.4    0.382  7.8   8.9   0.880   0.9   4.7
# 2    11.5  18.6   0.619   0.5   1.7    0.301  7.3  11.0   0.661   2.6   8.7
# 3     9.7  20.4   0.472   3.4   9.1    0.371  5.3   6.1   0.861   0.9   4.5
# 4    10.1  19.1   0.528   2.2   5.1    0.421  5.5   6.4   0.856   0.6   6.1
# ..    ...   ...     ...   ...   ...      ...  ...   ...     ...   ...   ...
# 254   1.1   2.6   0.430   1.0   2.4    0.423  0.2   0.3   0.667   0.2   1.1
# 255   1.2   2.7   0.437   0.1   0.4    0.250  0.8   1.2   0.698   1.2   1.0
# 256   1.5   3.7   0.418   0.1   0.2    0.500  0.1   0.1   0.750   0.3   1.5
# 257   1.1   3.0   0.364   0.4   1.3    0.306  0.1   0.3   0.538   0.8   1.6
# 258   1.0   1.9   0.529   0.3   0.9    0.375  0.2   0.2   0.727   0.8   1.2
#
#       REB  AST  STL  BLK  TOV   PTS   EFF
# 0     8.9  9.7  1.5  0.6  3.9  34.5  37.4
# 1     5.6  6.5  2.1  0.9  2.1  31.2  34.1
# 2    11.3  6.3  1.3  1.0  3.4  30.8  36.5
# 3     5.4  6.2  1.8  0.5  2.9  28.0  27.3
# 4     6.7  5.5  0.9  1.3  3.3  27.8  28.9
# ..    ...  ...  ...  ...  ...   ...   ...
# 254   1.3  0.5  0.3  0.1  0.3   3.5   3.6
# 255   2.2  0.6  0.3  0.7  0.6   3.3   4.5
# 256   1.8  3.4  0.4  0.1  1.1   3.2   5.6
# 257   2.4  0.4  0.2  0.4  0.3   2.8   3.8
# 258   2.0  0.9  0.3  0.1  0.4   2.4   4.4
#
# [259 rows x 25 columns]

# %%
games_url = 'https://cdn.nba.com/static/json/liveData/scoreboard/todaysScoreboard_00.json'

# %%
games_data = requests.get(url=games_url).json()

# %%
games_list = games_data['scoreboard']['games']

# %%
for game in games_list:
    home_team_name = game['homeTeam']['teamName']
    away_team_name = game['awayTeam']['teamName']
    game_time_et = game['gameEt']
    
    print(f"{home_team_name} V {away_team_name} at {game_time_et}")
# Out:
# Nets V Grizzlies at 2024-03-04T19:30:00Z
# Bucks V Clippers at 2024-03-04T20:00:00Z
# Timberwolves V Trail Blazers at 2024-03-04T20:00:00Z
# Jazz V Wizards at 2024-03-04T21:00:00Z
# Kings V Bulls at 2024-03-04T22:00:00Z
# Lakers V Thunder at 2024-03-04T22:30:00Z

# %%
games_data
# Out:
# {'meta': {'version': 1,
#   'request': 'https://nba-prod-us-east-1-mediaops-stats.s3.amazonaws.com/NBA/liveData/scoreboard/todaysScoreboard_00.json',
#   'time': '2024-03-04 07:34:41.3441',
#   'code': 200},
#  'scoreboard': {'gameDate': '2024-03-04',
#   'leagueId': '00',
#   'leagueName': 'National Basketball Association',
#   'games': [{'gameId': '0022300879',
#     'gameCode': '20240304/MEMBKN',
#     'gameStatus': 1,
#     'gameStatusText': '7:30 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2024-03-05T00:30:00Z',
#     'gameEt': '2024-03-04T19:30:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': None,
#     'gameSubLabel': None,
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612751,
#      'teamName': 'Nets',
#      'teamCity': 'Brooklyn',
#      'teamTricode': 'BKN',
#      'wins': 24,
#      'losses': 36,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612763,
#      'teamName': 'Grizzlies',
#      'teamCity': 'Memphis',
#      'teamTricode': 'MEM',
#      'wins': 20,
#      'losses': 41,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'BKN',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'MEM',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022300880',
#     'gameCode': '20240304/LACMIL',
#     'gameStatus': 1,
#     'gameStatusText': '8:00 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2024-03-05T01:00:00Z',
#     'gameEt': '2024-03-04T20:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': None,
#     'gameSubLabel': None,
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612749,
#      'teamName': 'Bucks',
#      'teamCity': 'Milwaukee',
#      'teamTricode': 'MIL',
#      'wins': 40,
#      'losses': 21,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612746,
#      'teamName': 'Clippers',
#      'teamCity': 'LA',
#      'teamTricode': 'LAC',
#      'wins': 39,
#      'losses': 20,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'MIL',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'LAC',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022300881',
#     'gameCode': '20240304/PORMIN',
#     'gameStatus': 1,
#     'gameStatusText': '8:00 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2024-03-05T01:00:00Z',
#     'gameEt': '2024-03-04T20:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': None,
#     'gameSubLabel': None,
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612750,
#      'teamName': 'Timberwolves',
#      'teamCity': 'Minnesota',
#      'teamTricode': 'MIN',
#      'wins': 42,
#      'losses': 19,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612757,
#      'teamName': 'Trail Blazers',
#      'teamCity': 'Portland',
#      'teamTricode': 'POR',
#      'wins': 17,
#      'losses': 42,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'MIN',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'POR',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022300882',
#     'gameCode': '20240304/WASUTA',
#     'gameStatus': 1,
#     'gameStatusText': '9:00 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2024-03-05T02:00:00Z',
#     'gameEt': '2024-03-04T21:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': None,
#     'gameSubLabel': None,
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612762,
#      'teamName': 'Jazz',
#      'teamCity': 'Utah',
#      'teamTricode': 'UTA',
#      'wins': 27,
#      'losses': 34,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612764,
#      'teamName': 'Wizards',
#      'teamCity': 'Washington',
#      'teamTricode': 'WAS',
#      'wins': 9,
#      'losses': 51,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'UTA',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'WAS',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022300883',
#     'gameCode': '20240304/CHISAC',
#     'gameStatus': 1,
#     'gameStatusText': '10:00 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2024-03-05T03:00:00Z',
#     'gameEt': '2024-03-04T22:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': None,
#     'gameSubLabel': None,
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612758,
#      'teamName': 'Kings',
#      'teamCity': 'Sacramento',
#      'teamTricode': 'SAC',
#      'wins': 34,
#      'losses': 25,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612741,
#      'teamName': 'Bulls',
#      'teamCity': 'Chicago',
#      'teamTricode': 'CHI',
#      'wins': 28,
#      'losses': 32,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'SAC',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'CHI',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022300884',
#     'gameCode': '20240304/OKCLAL',
#     'gameStatus': 1,
#     'gameStatusText': '10:30 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2024-03-05T03:30:00Z',
#     'gameEt': '2024-03-04T22:30:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'gameLabel': None,
#     'gameSubLabel': None,
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612747,
#      'teamName': 'Lakers',
#      'teamCity': 'Los Angeles',
#      'teamTricode': 'LAL',
#      'wins': 33,
#      'losses': 29,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612760,
#      'teamName': 'Thunder',
#      'teamCity': 'Oklahoma City',
#      'teamTricode': 'OKC',
#      'wins': 42,
#      'losses': 18,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'LAL',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'OKC',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}}]}}
